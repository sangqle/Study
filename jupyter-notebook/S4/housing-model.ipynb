# %%
#bai1
import sklearn
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split

# %%
# Read data from csv file
dt = pd.read_csv("Housing_2019.csv", index_col=0)
X = dt.iloc[:, [1, 2, 4, 10]]
Y = dt.price

# %%
plt.scatter(dt.lotsize, dt.price)
plt.show()

# %%
# using hold-out
X_train, X_test, y_train, y_test = train_test_split(
    X, Y, test_size=1/3.0, random_state=100)

# %%
plt.plot([1, 2, 3], [1, 2, 3])

# %%
# train model
model = linear_model.LinearRegression()
model.fit(X_train, y_train)
y_pred = model.predict(X_test)
plt.scatter(dt.lotsize, dt.price)
# xf=np.linspace(-50,150, 50)

plt.show()

# %%
np.array(X_test)[:,0].shape
# Out:
# (182,)

# %%
y_pred.shape
# Out:
# (182,)

# %%
# predict
y_pred = model.predict(X_test)

# %%
# The coefficients
print('Coefficients: \n', model.coef_)
# MSE and RMSE
err = mean_squared_error(y_test, y_pred)
err
rmse_err = np.sqrt(err)
round(rmse_err, 3)
# Out:
# Coefficients:
#  [4.75696965e+00 7.24077085e+03 9.17969453e+03 7.27173426e+03]
# 18916.353

# %%
model.predict([[3630, 3, 2, 0]])
# Out:
# array([58054.18712687])

# %%
X_test
# Out:
#      lotsize  bedrooms  stories  garagepl
# 55      3630         3        2         0
# 507     9800         4        2         2
# 497     4500         3        1         0
# 268     3600         2        1         0
# 154     3600         3        2         1
# ..       ...       ...      ...       ...
# 97      8250         3        1         2
# 34      4500         2        1         0
# 232     6615         4        2         1
# 480     5500         3        3         1
# 130     4600         3        2         2
#
# [182 rows x 4 columns]

# %%
y_pred
# Out:
# array([ 58054.18712687, 109188.92925724,  53013.05619266,  41491.01265259,
#         65183.21229599,  88826.60837114,  76599.9394639 ,  76839.04484484,
#         48344.13358183,  62298.06709739,  54036.55391566,  59428.53591379,
#         86021.23014741,  58101.7568234 ,  92666.89516868,  47816.52539319,
#         60169.7817243 ,  72420.23547981,  74702.32401511,  69080.8427832 ,
#         72597.65564432,  85748.67058985,  71536.76520387,  45772.28534056,
#         67441.51598303,  83401.14916983,  67086.00015731,  73264.88829406,
#         55057.29624529,  51846.34172932,  41657.50659046,  50634.57136601,
#         55057.29624529,  39516.87024648,  68767.54582587,  54486.4598869 ,
#         58601.238637  ,  66663.04530105,  68291.84886054,  70851.69239251,
#         64073.01063656,  61284.83256124,  67276.27894344,  43060.81263818,
#         41015.31568726,  60077.1561278 ,  41414.90113814,  84024.55979131,
#         62192.75072523,  57942.44144389,  47198.11933827,  68513.0910533 ,
#         79076.6483121 , 132330.83737297, 104334.90027281,  83976.99009478,
#         81691.1538912 ,  44864.36717656,  79220.02044148,  79220.02044148,
#         93681.2081875 ,  76404.48826523,  61094.55377511,  65218.18342473,
#         48731.78350469,  50062.47810933,  52568.32263395,  64486.2731379 ,
#         43023.41992074, 107792.80176787,  82778.82760064,  70741.68823199,
#         67420.24493132,  64464.49443546,  70243.46331667,  59233.2525611 ,
#         60464.89225842,  64059.40276739,  86980.31028717,  83739.30945809,
#         73786.89805764,  49051.16351125,  61717.0537599 , 106988.03244107,
#         47621.07419453,  61574.3446703 ,  74221.45463725,  41633.72174219,
#         47199.37623655,  68168.76150805,  47816.52539319,  58351.03918344,
#         91112.44457472,  40882.78357676,  69137.92641904,  60169.7817243 ,
#        120358.88786167,  69909.21854266,  77260.74280282,  83025.7640101 ,
#         60433.92885179,  91912.20933497,  73879.54668071,  50942.51749519,
#         51956.34588984,  59269.22053428,  66922.43545889,  60266.17801565,
#         75879.96470509,  41491.01265259,  53202.07808051,  88264.69209356,
#         55770.84169329,  59814.26589859,  62287.8901183 ,  83365.01335067,
#         57007.65380314,  81695.06940546,  72597.65564432,  43393.80051391,
#         52907.7398205 ,  67055.03675068,  63573.52882297,  79109.53165679,
#        110626.19713231,  60386.35915526,  83501.29312945, 118121.85522634,
#         92037.56288712,  73750.93008446,  43079.84051679,  57197.93258927,
#         70820.22133515,  64469.666848  ,  80886.3845644 ,  40920.1762942 ,
#         87110.16075514,  62192.75072523,  69755.07557569,  68599.31036555,
#         94959.32852905,  33536.6963525 ,  87687.59427033,  72799.5361538 ,
#         63099.65958785,  57768.76894767,  77890.7505811 ,  42680.25506592,
#         76001.22432737, 116471.00834103, 106988.03244107,  41586.15204566,
#         81399.30640119,  55532.99321062,  89400.10334551,  77656.64976671,
#         46961.52775388,  61377.63657336,  71944.53851448,  97456.73759703,
#         63551.98714779,  78709.61240125, 105519.63331338,  55057.29624529,
#         38827.10964675,  80479.86815206,  43393.80051391,  50598.93719749,
#         59662.04286968,  60315.75385801,  45877.60171272,  55913.55078288,
#         41110.45508033,  83301.00521021,  47270.73078135,  49445.32895269,
#         86736.20033967,  85395.16090996,  45772.28534056,  86766.24665277,
#         83401.14916983,  77211.91620801])
